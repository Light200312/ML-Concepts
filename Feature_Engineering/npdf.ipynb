# %%
import numpy as np
import pandas as pd

# %%
# Create a 2D numpy array
data = np.array([[10, 20], [30, 40], [50, 60]])

# Convert to DataFrame
df = pd.DataFrame(data)

print(df.values)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]]
